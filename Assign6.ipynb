# %% [markdown]
# # Text Generation

# %% [markdown]
# ## Introduction

# %% [markdown]
# Markov chains can be used for very basic text generation. Think about every word in a corpus as a state. We can make a simple assumption that the next word is only dependent on the previous word - which is the basic assumption of a Markov chain.
#
# Markov chains don't generate text as well as deep learning, but it's a good (and fun!) start.

# %% [markdown]
# ## Select Text to Imitate

# %% [markdown]
# In this notebook, we're specifically going to generate text in the style of Ali Wong, so as a first step, let's extract the text from her comedy routine.

# %%
# Read in the corpus, including punctuation!
import pandas as pd

data = pd.read_pickle('corpus.pkl')
data
# Out:
#             awardee                                         transcript  \
# Anne     transcript  The Nobel Prize in Physics 2023Pierre Agostini...
# Claudia  transcript  The Sveriges Riksbank Prize in Economic Scienc...
# Gerhard  transcript  The Nobel Prize in Chemistry 2007Gerhard ErtlS...
# Katalin  transcript  The Nobel Prize in Physiology or Medicine 2023...
# Leland   transcript  The Nobel Prize in Physiology or Medicine 2001...
# Paul     transcript  The Nobel Prize in Physiology or Medicine 2000...
# Pierre   transcript  The Nobel Prize in Physics 2023Pierre Agostini...
# Richard  transcript  The Nobel Prize in Physiology or Medicine 1993...
# Robert   transcript  The Nobel Prize in Chemistry 2012Robert J. Lef...
# Svante   transcript  The Nobel Prize in Physiology or Medicine 2022...
#
#           last_name
# Anne         Kariko
# Claudia       Paabo
# Gerhard    Agostini
# Katalin      Goldin
# Leland   L Huillier
# Paul       Hartwell
# Pierre         Ertl
# Richard     Roberts
# Robert    Lefkowitz
# Svante    Greengard

# %%
# Extract only Ali Wong's text
paul_text = data.transcript.loc['Paul']
paul_text[:200]
# Out:
# 'The Nobel Prize in Physiology or Medicine 2000Arvid CarlssonPaul GreengardEric KandelShare thisShare on Facebook: Transcript from an interview with Paul GreengardShare this content on FacebookFacebook'

# %% [markdown]
# ## Build a Markov Chain Function

# %% [markdown]
# We are going to build a simple Markov chain function that creates a dictionary:
# * The keys should be all of the words in the corpus
# * The values should be a list of the words that follow the keys

# %%
from collections import defaultdict

def markov_chain(text):
    '''The input is a string of text and the output will be a dictionary with each word as
       a key and each value as the list of words that come after the key in the text.'''
    
    # Tokenize the text by word, though including punctuation
    words = text.split(' ')
    
    # Initialize a default dictionary to hold all of the words and next words
    m_dict = defaultdict(list)
    
    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Convert the default dict back into a dictionary
    m_dict = dict(m_dict)
    return m_dict

# %%
# Create the dictionary for Ali's routine, take a look at it
paul_dict = markov_chain(paul_text)
paul_dict
# Out:
# {'The': ['Nobel',
#   'interviewer',
#   'other',
#   'situation',
#   'disadvantage',
#   'one',
#   'advantage',
#   'fact',
#   'only',
#   'picture',
#   'drug',
#   'problem',
#   'course',
#   'reason',
#   'students',
#   'nice',
#   'idea',
#   'scientists'],
#  'Nobel': ['Prize',
#   'Laureate',
#   'Prize',
#   'Prizes',
#   'Prize',
#   'Prize',
#   'Prize,',
#   'Prize',
#   'Prize',
#   'Prize',
#   'Laureates',
#   'Laureates',
#   'Laureates,',
#   'Prize,',
#   'Laureates',
#   'Laureates',
#   'Lecture',
#   'Prize',
#   'Symposium',
#   'Prize',
#   'Prize',
#   'Laureates',
#   'Prize',
#   'Prize',
#   'Prize.Select'],
#  'Prize': ['in',
#   'in',
#   'on',
#   'in',
#   'given',
#   'and',
#   'wanted',
#   'winners',
#   'money',
#   'with',
#   'Outreach',
#   'in'],
#  'in': ['Physiology',
#   'Physiology',
#   'the',
#   'the',
#   'biology',
#   'electronics',
#   'the',
#   'the',
#   'what',
#   'the',
#   'a',
#   'the',
#   'their',
#   'Physics',
#   'the',
#   'some',
#   'empty',
#   'college',
#   'the',
#   'the',
#   'biochemistry',
#   'physics',
#   'biology',
#   'our',
#   'understanding',
#   'biochemistry',
#   'the',
#   'itself',
#   '1936',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'fairness',
#   'our',
#   'a',
#   'the',
#   'the',
#   'selling',
#   'England',
#   'this',
#   'the',
#   'salary',
#   'the',
#   'terms',
#   'graduate',
#   'a',
#   'many',
#   'the',
#   'the',
#   'graduate',
#   'the',
#   'the',
#   'the',
#   'the',
#   'enormously',
#   'the',
#   'terms',
#   'the',
#   'the',
#   'the',
#   'the',
#   'that',
#   'that',
#   'parallel.',
#   'experiments',
#   'the',
#   'terms',
#   'Europe',
#   'that',
#   'other',
#   'my',
#   'for',
#   'on',
#   'the',
#   'the',
#   'those',
#   'the',
#   'their',
#   'interviewing',
#   'that',
#   'it,',
#   'the',
#   'science.',
#   'his',
#   'less',
#   'retrospect.',
#   'terms',
#   'mind,',
#   'lots',
#   'the',
#   'it',
#   'the',
#   'these',
#   'the',
#   'the',
#   'general',
#   'academia',
#   'this',
#   'a',
#   'this',
#   'the',
#   '1983',
#   'were',
#   'pharmacology',
#   'that',
#   'the',
#   'pharmacology,',
#   'a',
#   'England,',
#   'the',
#   'this',
#   'the',
#   'departments',
#   'all',
#   'terms',
#   'pharmacology',
#   'any',
#   'the',
#   'your',
#   'a',
#   'the',
#   'the',
#   'my',
#   'your',
#   'high',
#   'another',
#   'education',
#   'several',
#   'many',
#   'their',
#   'my',
#   'with',
#   'your',
#   'Stockholm,',
#   'science.',
#   'biomedical',
#   'the',
#   'as',
#   'science',
#   'her',
#   'a',
#   'the',
#   'on',
#   'my',
#   'all',
#   'this',
#   'identifying',
#   '2023,',
#   'different'],
#  'Physiology': ['or', 'or'],
#  'or': ['Medicine',
#   'Medicine,',
#   'was',
#   'mathematics',
#   'engineering,',
#   'medical',
#   'the',
#   'something,',
#   'very,',
#   'ten',
#   'this',
#   'something',
#   'something,',
#   'it’s',
#   'anything',
#   'lack',
#   'a',
#   'GPCRs.',
#   'this',
#   'almost',
#   'this',
#   'inertia,',
#   '90%',
#   '90%',
#   'being',
#   'tens',
#   'say',
#   'whatever.',
#   'in',
#   'a',
#   'the',
#   'no.',
#   'don’t',
#   'whatever,',
#   'publications,',
#   'post-doc',
#   'here',
#   'here.',
#   'your',
#   'embarrass',
#   'they’re',
#   'can',
#   'categories',
#   'categories'],
#  'Medicine': ['2000Arvid'],
#  '2000Arvid': ['CarlssonPaul'],
#  'CarlssonPaul': ['GreengardEric'],
#  'GreengardEric': ['KandelShare'],
#  'KandelShare': ['thisShare'],
#  'thisShare': ['on'],
#  'on': ['Facebook:',
#   'FacebookFacebookTweet:',
#   'TwitterTwitterShare',
#   'LinkedIn:',
#   'LinkedInLinkedInShare',
#   'unravelling',
#   'radar.Paul',
#   'the',
#   'the',
#   'so',
#   'to',
#   'to',
#   'the',
#   'and',
#   'to',
#   'what',
#   'that',
#   'of',
#   'another,',
#   'another.',
#   'second',
#   'the',
#   'the',
#   'the',
#   'committees',
#   'that',
#   'time',
#   'that,',
#   'in',
#   'the',
#   'this',
#   'your',
#   'the',
#   'this',
#   'that',
#   'biotech',
#   'them',
#   'partnering',
#   'the',
#   'who',
#   'these',
#   'longer',
#   'and',
#   'right',
#   'the',
#   'it,',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the'],
#  'Facebook:': ['Transcript'],
#  'Transcript': ['from', 'from', 'from', 'from', 'from'],
#  'from': ['an',
#   'an',
#   'an',
#   'an',
#   'an',
#   'school.',
#   'that',
#   'a',
#   'the',
#   'my',
#   'one',
#   'committees',
#   'these',
#   'the',
#   'ever',
#   'you?',
#   'some',
#   'anywhere',
#   'women.',
#   'various',
#   'nearby',
#   'distant',
#   'an',
#   'effective'],
#  'an': ['interview',
#   'interview',
#   'interview',
#   'interview',
#   'interview',
#   'electronic',
#   'amazing',
#   'amazing',
#   'enzyme',
#   'enzyme',
#   'enzyme.Nowadays',
#   'electro',
#   'interesting',
#   'area',
#   'excellent',
#   'exception,',
#   'extra',
#   'extraordinary',
#   'impossible',
#   'option.',
#   'interesting',
#   'interesting',
#   'understandable',
#   'expert',
#   'attractive',
#   'attractive',
#   'interview',
#   'increasing',
#   'increasingly',
#   'award',
#   'award',
#   'award',
#   'award',
#   'amazing',
#   'interview'],
#  'interview': ['with',
#   'with',
#   'with',
#   'with',
#   'with',
#   'with',
#   'with',
#   'the',
#   'with'],
#  'with': ['Paul',
#   'Paul',
#   'Paul',
#   'Paul',
#   'Paul',
#   'the',
#   'Nobelprize.org.Paul',
#   'these',
#   'no',
#   'my',
#   'the',
#   'lots',
#   'for',
#   'the',
#   'the',
#   'the',
#   'an',
#   'gigantic',
#   'these',
#   'or',
#   'the',
#   'reference',
#   'a',
#   'pictures',
#   'lots',
#   'Jobs,',
#   'me',
#   'that',
#   'me,',
#   'Adam',
#   'Adam',
#   'you',
#   'what',
#   'fresh',
#   'a',
#   'this',
#   'all',
#   'it',
#   'Paul'],
#  'Paul': ['GreengardShare',
#   'GreengardShare',
#   'GreengardShare',
#   'GreengardShare',
#   'GreengardInterview',
#   'Greengard,',
#   'Nurse',
#   'Greengard.'],
#  'GreengardShare': ['this', 'this', 'this', 'this'],
#  'this': ['content',
#   'content',
#   'content',
#   'content',
#   'pageTranscript',
#   'interview',
#   'emerging',
#   'didn’t',
#   'boundary',
#   'company',
#   'being',
#   'system',
#   'had',
#   'basic',
#   'is',
#   'was',
#   'comes',
#   'guy’s',
#   'woman’s',
#   'woman',
#   'was',
#   'is',
#   'is',
#   'way',
#   'sort',
#   'region,',
#   'P11',
#   'yet',
#   'sort',
#   'software',
#   'slow',
#   'enzyme',
#   'receptor',
#   'drug',
#   'one',
#   'new',
#   'programme',
#   'but',
#   'area',
#   'demonstration',
#   'gut',
#   'young',
#   'idea',
#   'bias',
#   'person’s',
#   'whole',
#   'happens',
#   'young',
#   'but',
#   'can’t',
#   'with',
#   'Nobel',
#   'should',
#   'meant',
#   'is',
#   'and',
#   'sort',
#   'time',
#   'text?',
#   'sectionMLA'],
#  'content': ['on', 'on', 'on', 'via'],
#  'FacebookFacebookTweet:': ['Transcript'],
#  'TwitterTwitterShare': ['on'],
#  'LinkedIn:': ['Transcript'],
#  'LinkedInLinkedInShare': ['via'],
#  'via': ['Email:', 'EmailEmail'],
#  'Email:': ['Transcript'],
#  'EmailEmail': ['this'],
#  'pageTranscript': ['from'],
#  'GreengardInterview': ['with'],
#  'the': ['2000',
#   'year',
#   'pathways',
#   'nervous',
#   'army',
#   'Navy.That',
#   'second',
#   'field',
#   'war',
#   'Massachusetts',
#   'Radiation',
#   'development',
#   'big',
#   'United',
#   'water',
#   'curvature',
#   'Earth,',
#   'tops',
#   'ships',
#   'curvature',
#   'Earth',
#   'days',
#   'concept',
#   'image',
#   'aircraft',
#   'Navy',
#   'time,',
#   'highest',
#   'United',
#   'next',
#   'English',
#   'Germans',
#   'British',
#   'decision',
#   'study',
#   'dropping',
#   'atom',
#   'only',
#   'Atomic',
#   'country',
#   'University',
#   'brain',
#   'interest',
#   'electrical',
#   'time',
#   'qualifying',
#   'work',
#   'Nobel',
#   'ionic',
#   'nerve',
#   'property',
#   'biochemistry',
#   'electricity.',
#   'main',
#   'department,',
#   '1950s',
#   'brain,',
#   'Nobel',
#   'brain.',
#   'background',
#   'scientists',
#   'field.',
#   'brain,',
#   'biochemistry',
#   'underlying',
#   'brain’s',
#   'brain',
#   'liver,',
#   'pancreas',
#   'muscle,',
#   'two',
#   'electrical',
#   'best',
#   'faculty',
#   'joint',
#   'Moccollum',
#   'biology',
#   'more',
#   'country',
#   'interface',
#   'biochemical',
#   'nerve',
#   'two',
#   'biochemical',
#   'time',
#   'difference',
#   'university',
#   'things',
#   'other',
#   'committee',
#   'basic',
#   'action',
#   'head',
#   'biochemistry',
#   'basis',
#   'first',
#   'curriculum,',
#   'functions',
#   'ensuing',
#   'same',
#   'meanwhile',
#   'projects',
#   'basic',
#   'same.Earl',
#   'actions',
#   'cyclic',
#   'liver,',
#   'liver',
#   'brain',
#   'levels',
#   'brain',
#   'synapse,',
#   'junction',
#   'brain',
#   'brain,',
#   '1960s.',
#   'disadvantage',
#   'work.',
#   'field',
#   'signal',
#   'time',
#   'foundation',
#   'brain.Right.',
#   'wrong',
#   'right',
#   'side',
#   'reviewers',
#   'grant',
#   'two',
#   'competition',
#   'work',
#   'philosophy',
#   'United',
#   'next',
#   'United',
#   'grant',
#   'more',
#   'bias',
#   'first',
#   'Nobel',
#   'Nobel',
#   'institute',
#   'Nobel',
#   'bureaucracy.So',
#   'bar',
#   'earlier',
#   'sort',
#   'main',
#   'great',
#   'wrong',
#   'way',
#   'way',
#   'basic',
#   'rule',
#   'exception',
#   'rule',
#   'exception',
#   'main',
#   'prevailing',
#   'preceding',
#   'way',
#   'experiments',
#   'way',
#   'system',
#   'experiments',
#   'way',
#   'number',
#   'end',
#   'balance',
#   'question',
#   'nature',
#   'same',
#   'same',
#   'body',
#   'foundation',
#   'funding',
#   'same',
#   'intracellular',
#   'way',
#   'responsiveness',
#   'neurons',
#   'following:',
#   'signalling',
#   'hardware',
#   'brain',
#   'slow',
#   'software',
#   'brain,',
#   'fast',
#   'signalling',
#   'ds',
#   'same',
#   'disease',
#   'dopamine',
#   'brain.',
#   'received',
#   'puzzle',
#   'whole',
#   'whole',
#   'puzzle',
#   'pharmaceutical',
#   'major',
#   'major',
#   'information',
#   'pharmaceutical',
#   'major',
#   'drug',
#   'right',
#   'pharmaceutical',
#   'biological',
#   'drug',
#   'drug',
#   'drug',
#   'best',
#   'approach',
#   'pharmaceutical',
#   'literature',
#   'literature',
#   'momentum',
#   'drug',
#   'finishing',
#   'attitude',
#   'appreciation',
#   'better',
#   'manpower',
#   'answer',
#   'big',
#   'research',
#   'new',
#   'exciting',
#   'inertial',
#   'big',
#   'basic',
#   'order',
#   'pharmaceutical',
#   'theme',
#   'departments',
#   'perceived',
#   'university',
#   '‘Adam',
#   'Morphology',
#   'pharmacology',
#   'electrophysiology',
#   'biochemistry',
#   'laboratory',
#   'people',
#   'brain',
#   'structure',
#   'cutting',
#   'question',
#   'lack',
#   'next',
#   'molecular',
#   'research',
#   'molecular',
#   'molecular',
#   'lab.',
#   'post-docs',
#   'lab?Paul',
#   'other',
#   'field,',
#   'door',
#   'person,',
#   'best',
#   'letters',
#   'letter,',
#   'chemistry',
#   'laboratory,',
#   'laboratory,',
#   'chemistry',
#   'callipers',
#   'people',
#   'lab',
#   'most',
#   'years',
#   'best',
#   'kinds',
#   'department',
#   'pharmacology',
#   'end',
#   'more',
#   'best',
#   'system',
#   'dean',
#   'most',
#   'nice',
#   'most',
#   'brain',
#   'system',
#   'more',
#   'students',
#   'students',
#   'professor’s',
#   'post-doctorate',
#   'presenter',
#   'speaker',
#   'students',
#   'same',
#   'students',
#   'end',
#   'compromise',
#   'Pearl',
#   'Nobel',
#   'then',
#   'president',
#   'university',
#   'prize',
#   'most',
#   'world',
#   'day',
#   'Nobel',
#   'cameras',
#   'response.',
#   'president',
#   'award',
#   'award',
#   'first',
#   'first',
#   'supreme',
#   'United',
#   'presenters,',
#   'dean',
#   'Washington',
#   'presenter.Paul',
#   'very',
#   'award.',
#   'committees',
#   'costs',
#   'costs',
#   'people',
#   'committee',
#   'university',
#   'expenses',
#   'university',
#   'highlights.',
#   'highlight',
#   'people',
#   'awards',
#   'committee.',
#   'people',
#   'money',
#   'deliberations',
#   'winner.Yes,',
#   'award',
#   'interviewDid',
#   'time',
#   'errors',
#   'top',
#   'pageNobel',
#   'greatest',
#   'oppression',
#   'history',
#   'Nobel',
#   'category',
#   'category',
#   'year',
#   'year'],
#  '2000': ['Nobel', 'and'],
#  'Laureate': ['in'],
#  'Medicine,': ['Paul'],
#  'Greengard,': ['13', 'welcome'],
#  '13': ['June'],
#  'June': ['2008.'],
#  '2008.': ['The'],
#  'interviewer': ['is'],
#  'is': ['Adam',
#   'called',
#   'such',
#   'top',
#   'secret',
#   'applying',
#   'interesting',
#   'quite',
#   'present',
#   'heretical,',
#   'ridiculous,',
#   'that',
#   'forced',
#   'written',
#   'really',
#   'the',
#   'right.',
#   'the',
#   'accepted.',
#   'such',
#   'basically',
#   'working',
#   'the',
#   'modulate',
#   'incomparably',
#   'to',
#   'a',
#   'implicated',
#   'like',
#   'missing.',
#   'already',
#   'taking',
#   'sufficiently',
#   'say',
#   'the',
#   'that',
#   'there,',
#   'completed',
#   'partly',
#   'an',
#   'spent',
#   'in',
#   'done',
#   'whether',
#   'a',
#   'that',
#   'a',
#   'no',
#   'basically',
#   'but',
#   'exciting.',
#   'the',
#   'really',
#   'we',
#   'I',
#   'extremely',
#   'a',
#   'all',
#   'an',
#   'very',
#   'the',
#   'named'],
#  'Adam': ['Smith,', 'Smith', 'Smith'],
#  'Smith,': ['Editor-in-Chief'],
#  'Editor-in-Chief': ['of'],
#  'of': ['Nobelprize.org.Paul',
#   'signalling',
#   'electronics.',
#   'time',
#   'Technology',
#   'a',
#   'the',
#   'the',
#   'the',
#   'the',
#   'very',
#   'us',
#   'them',
#   'secret',
#   'London',
#   'people',
#   'biological',
#   'the',
#   'biophysics',
#   'Pennsylvania',
#   'neuro',
#   'the',
#   'nerve',
#   'the',
#   'nerve',
#   'the',
#   'people',
#   'enzymes.',
#   'neuroscience,',
#   'nerve',
#   'an',
#   'my',
#   'an',
#   'the',
#   'enzymology',
#   'the',
#   'work,',
#   'biochemistry',
#   'Novartis.',
#   'the',
#   'understanding',
#   'drugs',
#   'the',
#   'stuff',
#   'diseases',
#   'hands',
#   'the',
#   'the',
#   'medicine',
#   'hormones',
#   'cyclic',
#   'a',
#   'negative',
#   'the',
#   'thing.',
#   'the',
#   'support',
#   'research',
#   'thing.I’ve',
#   'being',
#   'amazing,',
#   'inner',
#   'self-belief.Paul',
#   'thinking.The',
#   'the',
#   'people',
#   'thing',
#   'people',
#   'how',
#   'funding',
#   'ability',
#   'knowledge',
#   'funding',
#   'thing.Paul',
#   'the',
#   'how',
#   'the',
#   'the',
#   'what',
#   'these',
#   'them.',
#   'these',
#   'them.Bearing',
#   'your',
#   'diseases',
#   'the',
#   'key',
#   'the',
#   'pieces',
#   'their',
#   'the',
#   'knowledge',
#   'these',
#   'this',
#   'research',
#   'terms',
#   'view',
#   'programmes.',
#   'this',
#   'effort',
#   'academic',
#   'staged',
#   'that',
#   'the',
#   'the',
#   'biotech.',
#   'changing',
#   'approval',
#   'thing',
#   'millions',
#   'millions',
#   'millions',
#   'dollars.',
#   'drugs',
#   'Immunology’',
#   'department.',
#   'man',
#   'the',
#   'chemical',
#   'equipment',
#   'various',
#   'the',
#   'pharmacology',
#   'pharmacologists',
#   'departments',
#   'teaching',
#   'many',
#   'your',
#   'people',
#   'Apple.Steve',
#   'the',
#   'us',
#   'like',
#   'applicants',
#   'laboratory',
#   'letters',
#   'recommendation',
#   'recommendation,',
#   'them?Paul',
#   'the',
#   'how',
#   'students',
#   'that',
#   'times,',
#   'my',
#   'students,',
#   'the',
#   'the',
#   'the',
#   'how',
#   'colleagues',
#   'the',
#   'the',
#   'course',
#   'the',
#   'the',
#   'opinion',
#   'the',
#   'people',
#   'the',
#   'emails',
#   'these',
#   'tremendous',
#   'Stanford',
#   'the',
#   'these',
#   'people.',
#   'not',
#   'the',
#   'the',
#   'my',
#   'the',
#   'this',
#   'discrimination.With',
#   'the',
#   'women.See',
#   'the'],
#  'Nobelprize.org.Paul': ['Greengard,', 'Greengard:'],
#  'welcome': ['to', 'new'],
#  'to': ['Stockholm',
#   'this',
#   'receive',
#   'experimental',
#   'work',
#   'research',
#   'the',
#   'the',
#   'an',
#   'go',
#   'see',
#   'look',
#   'know',
#   'bomb',
#   'know',
#   'be',
#   'all',
#   'doing',
#   'me',
#   'study',
#   'move',
#   'college,',
#   'study',
#   'college.',
#   'go',
#   'graduate',
#   'go',
#   'graduate',
#   'me,',
#   'do',
#   'kill',
#   'a',
#   'study',
#   'studying',
#   'start',
#   'do',
#   'get',
#   'a',
#   'be',
#   'be',
#   'get',
#   'accept',
#   'keep',
#   'measure',
#   'study',
#   'each',
#   'unite',
#   'bring',
#   'persuade',
#   'do',
#   'the',
#   'do',
#   'work',
#   'understand',
#   'use',
#   'new',
#   'a',
#   'them',
#   'study',
#   'university',
#   'learn',
#   'do',
#   'go',
#   'give',
#   'the',
#   'me',
#   'be',
#   'be',
#   'go',
#   'work',
#   'move',
#   'have',
#   'myself,',
#   'realise',
#   'do',
#   'his',
#   'put',
#   'do',
#   'be',
#   'committees,',
#   'ask',
#   'have',
#   'do',
#   'go',
#   'your',
#   'return',
#   'the',
#   'work,',
#   'figure',
#   'other',
#   'be.',
#   'answer',
#   'prove',
#   'work.',
#   'be.',
#   'ask',
#   'get',
#   'what',
#   'continue.Paul',
#   'be',
#   'solve',
#   'be',
#   'come',
#   'be',
#   'be',
#   'talk',
#   'be',
#   'target',
#   'pursue',
#   'pursuing',
#   'get',
#   'get',
#   'find',
#   'develop',
#   'do',
#   'picking',
#   'do',
#   'wait',
#   'come',
#   'be',
#   'these',
#   'talk',
#   'Rockefeller,',
#   'a',
#   'the',
#   'be',
#   'homogenize',
#   'be',
#   'do,',
#   'work',
#   'go',
#   'a',
#   'students',
#   'go',
#   'places',
#   'be',
#   'teaching,',
#   'somebody,',
#   'come',
#   'his',
#   'the',
#   'the',
#   'the',
#   'my',
#   'you.',
#   'this',
#   'go',
#   'go',
#   'me.',
#   'come',
#   'college',
#   'go',
#   'graduate',
#   'the',
#   'me',
#   'do',
#   'oblige',
#   'rotate',
#   'do',
#   'go',
#   'work',
#   'do',
#   'my',
#   'go',
#   'get',
#   'keep',
#   'have',
#   'listen',
#   'them',
#   'put',
#   'be',
#   'try',
#   'get',
#   'say',
#   'know',
#   'draw',
#   'the',
#   'embarrass',
#   'get',
#   'be',
#   'sum',
#   'give',
#   'deliver',
#   'do',
#   'hand',
#   'do',
#   'finish',
#   'endow.',
#   'start',
#   'my',
#   'recognise',
#   'them',
#   'them.',
#   'present',
#   'this.',
#   'be',
#   'have',
#   'do',
#   'work',
#   'me,',
#   'do',
#   'thank',
#   'speak',
#   'us,',
#   'let',
#   'report',
#   'topBack',
#   'the',
#   'humankind.',
#   'fighting',
#   'filter',
#   'filter',
#   'search'],
#  'Stockholm': ['and'],
#  'and': ['to',
#   'your',
#   'that',
#   'due',
#   'so',
#   'then',
#   'then',
#   'work',
#   'so',
#   'the',
#   'not',
#   'it’s',
#   'they',
#   'what',
#   'there',
#   'these',
#   'physics',
#   'then',
#   'maths',
#   'that’s',
#   'physics,',
#   'the',
#   'it',
#   'mathematics',
#   'medical',
#   'one',
#   'I',
#   'that’s',
#   'neuro',
#   'various',
#   'in',
#   'then',
#   'he',
#   'I',
#   'so',
#   'this',
#   'membranes',
#   'so',
#   'chemical',
#   'indeed',
#   'Loewi',
#   'yet',
#   'action',
#   'were',
#   'homogenize',
#   'for',
#   'homogenize',
#   'use',
#   'the',
#   'then',
#   'it',
#   'a',
#   'so.',
#   'biochemistry',
#   'was',
#   'continued',
#   'virtually',
#   'truly',
#   'I',
#   'I',
#   'to',
#   'unless',
#   'I',
#   'how',
#   'develop',
#   'it',
#   'so',
#   'comforting',
#   'I',
#   'one',
#   'diseases',
#   'I',
#   'when',
#   'I’ve',
#   'broke',
#   'muscle',
#   'since',
#   'work',
#   'act',
#   'we',
#   'not',
#   'Krebs',
#   'then',
#   'I',
#   'biochemistry',
#   'once',
#   'said,',
#   'it',
#   'it',
#   'disadvantages.',
#   'that',
#   'by',
#   'people',
#   'they',
#   'the',
#   'they',
#   'you',
#   'when',
#   'it’s',
#   'let’s',
#   'it’s',
#   'that',
#   'with',
#   'I',
#   'this',
#   'it',
#   'then',
#   'now',
#   'occasionally',
#   'good,',
#   'there',
#   'apparent',
#   'the',
#   'everybody',
#   'finally',
#   'if',
#   'major',
#   'they',
#   'it',
#   'if',
#   'the',
#   'I',
#   'so',
#   'then',
#   'picks',
#   'you',
#   'prove',
#   'then',
#   'I',
#   'I',
#   'nobody',
#   'you',
#   'also',
#   'I',
#   'others',
#   'there',
#   'others',
#   'a',
#   'I’d',
#   'I',
#   'I',
#   'by',
#   'large',
#   'such',
#   'they',
#   'so',
#   'by',
#   'large,',
#   'myself',
#   'four',
#   'you',
#   'then',
#   'more',
#   '80',
#   'they’re',
#   'like',
#   'don’t',
#   'then',
#   'do',
#   'then',
#   'Amgen,',
#   'I',
#   'what',
#   'if',
#   'the',
#   'they',
#   'so',
#   'is',
#   'biochemistry',
#   'molecular',
#   'the',
#   'productive',
#   'the',
#   'students',
#   'mostly',
#   'so',
#   'why',
#   'so',
#   'then',
#   'I',
#   'you',
#   'you',
#   'you',
#   'your',
#   'study',
#   'stay',
#   'then',
#   'then',
#   'they',
#   'then',
#   'applied',
#   'he',
#   'then',
#   'talented',
#   'then',
#   'this',
#   'then',
#   'finds',
#   'as',
#   'have',
#   'one',
#   'finally,',
#   'it',
#   'students',
#   'bushy',
#   'they',
#   'I',
#   'often',
#   'it',
#   'it’s',
#   'think,',
#   'I',
#   'I',
#   'make',
#   'I’d',
#   'talk',
#   'of',
#   'he’ll',
#   'I',
#   'nothing',
#   'then',
#   'a',
#   'all',
#   'he',
#   'so',
#   'the',
#   'could',
#   'these',
#   'then',
#   'they’ve',
#   'so',
#   'running,',
#   'some',
#   'they',
#   'thank',
#   'my',
#   'there’s',
#   'to',
#   'laureatesNobel',
#   'discoveries',
#   'attosecond',
#   'laureatesLook',
#   'laureates',
#   'discover'],
#  'Greengard:': ['Thank',
#   'I',
#   'I',
#   'It',
#   'It',
#   'I',
#   'When',
#   'No,',
#   'Correct.…',
#   'It',
#   'Yes,',
#   'I',
#   'It',
#   'Pretty',
#   'Yes,',
#   'It',
#   'That’s',
#   'At',
#   'I',
#   'Yes.',
#   'That’s',
#   'You’ve',
#   'Nobody',
#   'This',
#   'My',
#   'Who',
#   'It’s',
#   'I',
#   'Yes,',
#   'A',
#   'We',
#   'Yes,',
#   'One',
#   'At',
#   'It',
#   'There',
#   'Steve',
#   'I',
#   'What',
#   'Yes,',
#   'That',
#   'They',
#   'Yes.They’ll',
#   'Are',
#   'That’s',
#   'Yes.',
#   '…',
#   'No,',
#   '…',
#   'No,',
#   'With',
#   'It’s',
#   'It',
#   'My',
#   'Thank'],
#  'Thank': ['you.It’s', 'you.Watch', 'you'],
#  'you.It’s': ['been'],
#  'been': ['almost',
#   'sent',
#   'not',
#   'known',
#   'quite',
#   'following',
#   'extremely',
#   'very',
#   'found',
#   'a',
#   'that',
#   'one',
#   'reading',
#   'several',
#   'going',
#   'a',
#   'very',
#   'great',
#   'discrimination',
#   'very',
#   'fascinating.Paul'],
#  'almost': ['eight', '15', 'inverse', 'by', 'like', 'all', 'all', 'a'],
#  'eight': ['years', 'years.', 'years,'],
#  'years': ['since',
#   'in',
#   'ago.If',
#   'and',
#   'would',
#   'and',
#   'although',
#   'in',
#   'until',
#   'later',
#   'in',
#   'people',
#   'now?Paul',
#   'until'],
#  'since': ['you', 'I', 'hormones', 'he'],
#  'you': ['came',
#   'were',
#   'find',
#   'can',
#   'say',
#   'on',
#   'went',
#   'made',
#   'from',
#   'could',
#   'subsequently',
#   'had',
#   'went',
#   'have',
#   'could',
#   'just',
#   'feel',
#   'were',
#   'crusading',
#   'could',
#   'an',
#   'stayed',
#   'must',
#   'get',
#   'left',
#   'did',
#   'were',
#   'talking',
#   'could',
#   'weren’t',
#   'were',
#   'know',
#   'give',
#   'have',
#   'money',
#   'and',
#   'were',
#   'never',
#   'could',
#   'think',
#   'shouldn’t',
#   'say,',
#   'could',
#   'solve',
#   'feel',
#   'have',
#   'can',
#   'wonder',
#   'and',
#   'think',
#   'take',
#   'say',
#   'can’t',
#   'get',
#   'felt',
#   'worked',
#   'see',
#   'illustrated',
#   'have',
#   'look',
#   'choose',
#   'just',
#   'think',
#   'see',
#   'sort',
#   'see',
#   'invite',
#   'think',
#   'have',
#   'publish',
#   'want',
#   'Sir?',
#   'get',
#   'know,',
#   'don’t',
#   'about',
#   'started',
#   'invite',
#   'start',
#   'should',
#   'suggest',
#   'very',
#   'find',
#   'for',
#   'would',
#   'would',
#   'would'],
#  'came': ['to', 'out', 'for', 'out', 'in'],
#  'receive': ['your'],
#  'your': ['Nobel',
#   'work',
#   'first',
#   'first',
#   'degree',
#   'thesis.',
#   'brain',
#   'work',
#   'grant',
#   'earlier',
#   'work',
#   'work’s',
#   'point',
#   'Nobel',
#   'co-workers.',
#   'co-workers',
#   'gut',
#   'mentorship',
#   'colleagues',
#   'mind',
#   'thinking',
#   'own',
#   'share',
#   'mother.Paul',
#   'assistance'],
#  'year': ['2000',
#   'and',
#   'and',
#   'and',
#   'these',
#   'and',
#   'and',
#   'by',
#   'you',
#   'by'],
#  'work': ['on',
#   'was',
#   'on',
#   'with',
#   'for',
#   'in',
#   'ever',
#   'on',
#   'on',
#   'which',
#   'in',
#   'because',
#   'wasn’t',
#   'because,',
#   'in',
#   'with',
#   'with',
#   'wasn’t',
#   'well,',
#   'and'],
#  'unravelling': ['the'],
#  'pathways': ['of', 'that', 'and', 'that'],
#  'signalling': ['in',
#   'in',
#   'mechanisms',
#   'is',
#   'goes',
#   'pathways',
#   'itself',
#   'pathways',
#   'pathways,',
#   'pathways',
#   'that',
#   'pathways.In'],
#  'nervous': ['system'],
#  'system': ['continues,', 'is', 'has', 'and', 'which', 'notes', 'works'],
#  'continues,': ['but'],
#  'but': ['your',
#   'in',
#   'that’s',
#   'I',
#   'our',
#   'for',
#   'people',
#   'how',
#   'we',
#   'in',
#   'that’s',
#   'I',
#   'I',
#   'the',
#   'it',
#   'it’s',
#   'with',
#   'most',
#   'let’s',
#   'what',
#   'in',
#   'in',
#   'it’s',
#   'I',
#   'the',
#   'I’ve',
#   'simply',
#   'there',
#   'their',
#   'if',
#   'it',
#   'they’ve',
#   'the',
#   'we',
#   'I',
#   'it',
#   'I',
#   'there',
#   'they',
#   'it',
#   'there’s',
#   'before',
#   'you',
#   'this',
#   'especially',
#   'often',
#   'it’s',
#   'often',
#   'they',
#   'the',
#   'by',
#   'it',
#   'there’s',
#   'some',
#   'the',
#   'they',
#   'I',
#   'I’ve',
#   'she'],
#  'first': ['introduction',
#   'exposure',
#   'part',
#   'grant',
#   'reading',
#   'one',
#   'woman'],
#  'introduction': ['to'],
#  'experimental': ['work'],
#  'was': ['not',
#   'during',
#   'straight',
#   'not',
#   'these',
#   'in',
#   'you’d',
#   'like',
#   'an',
#   'like',
#   'an',
#   'they',
#   'a',
#   'amazing',
#   'going',
#   'it',
#   'that',
#   'interested',
#   'what',
#   'good',
#   'going',
#   'from',
#   'at',
#   'going',
#   'still',
#   'the',
#   'impossible',
#   'the',
#   'electrophysiologists',
#   'electrophysiology',
#   'studying',
#   'biochemistry',
#   'not',
#   'considered',
#   'in',
#   'a',
#   'one',
#   'interested',
#   'doing',
#   'offered',
#   'Geigy',
#   'interested',
#   'like',
#   'quite',
#   'there',
#   'a',
#   'done',
#   'very',
#   'obliged',
#   'so',
#   'more',
#   'very,',
#   'educated',
#   'to',
#   'the',
#   'in',
#   'phosphorylation',
#   'it',
#   'in',
#   'so',
#   'going',
#   '40',
#   'unusual',
#   'positively',
#   'interesting.',
#   'right.',
#   'right',
#   'right',
#   'it’s',
#   'not',
#   'Earl',
#   'doing,',
#   'the',
#   'that',
#   'nice',
#   'right,',
#   'fairly',
#   'that',
#   'not',
#   'on',
#   'really',
#   'applying',
#   'so',
#   'the',
#   'loose',
#   'criticising',
#   'burdened',
#   'self-belief,',
#   'going',
#   'not',
#   'only',
#   'talking',
#   'when',
#   'in',
#   'dominated',
#   'very',
#   'telling',
#   'happy',
#   'young,',
#   'an',
#   'in',
#   'one',
#   'involved',
#   'reading',
#   'him,',
#   'in,',
#   'so',
#   'right.',
#   'going',
#   'very',
#   'to',
#   'not',
#   'just',
#   'very',
#   'Sandra',
#   'the',
#   'the',
#   'a',
#   'very',
#   'quite'],
#  'not': ['in',
#   'quite',
#   'be',
#   'very',
#   'many',
#   'that',
#   'interested',
#   'interested',
#   'crusading',
#   'oppose',
#   'agree',
#   'only',
#   'done',
#   'get',
#   'much',
#   'believing',
#   'trying',
#   'always.Yes,',
#   'right?Who',
#   'believed',
#   'have',
#   'start',
#   'a',
#   'infrequently,',
#   'very',
#   'appreciated,',
#   'right',
#   'do',
#   'to',
#   'a',
#   'in',
#   'get',
#   'an',
#   'saying,',
#   'like'],
#  'biology': ['but', 'to', 'department', 'and', 'and'],
#  'electronics': ['because'],
#  'because': ['you',
#   'that’s',
#   'these',
#   'peripheral',
#   'the',
#   'everything',
#   'as',
#   'nowadays,',
#   'you',
#   'I’ve',
#   'life',
#   'Nobel',
#   'it’s',
#   'they’re',
#   'if',
#   'science',
#   'that’s',
#   'I',
#   'we’ll',
#   'maybe',
#   'they’re',
#   'they',
#   'I’ve',
#   'they’re',
#   'they',
#   'the',
#   'they',
#   'if',
#   'then',
#   'I'],
#  'were': ['drafted',
#   'about',
#   'probably',
#   'several',
#   'all',
#   'trying',
#   'crossed',
#   'dozens',
#   'only',
#   'doing',
#   'using',
#   'purely',
#   'very',
#   'two',
#   'not',
#   'not',
#   'biochemists',
#   'doing',
#   'you',
#   'avant',
#   'doing',
#   'somewhat',
#   'really',
#   'just',
#   'just',
#   'getting',
#   'prizes',
#   'telling',
#   'right',
#   'dominated',
#   'called',
#   'talking',
#   'doing',
#   'talking',
#   'talking',
#   'not',
#   'right,',
#   'wrong',
#   'right.',
#   'very',
#   'much',
#   'picked',
#   'awarded'],
#  'drafted': ['by'],
#  'by': ['the',
#   'purely',
#   'committees',
#   'one',
#   'Earl',
#   'the',
#   'some',
#   'the',
#   'definition',
#   'dogma',
#   'this',
#   'definition',
#   'lack',
#   'far',
#   'organic',
#   'and',
#   'synthetic',
#   'and',
#   'a',
#   'the',
#   'individuals',
#   'which',
#   'your',
#   'the',
#   'asking',
#   'donating',
#   'the',
#   'another',
#   'sending',
#   'one-Choose',
#   'one+Explore'],
#  'army': ['to'],
#  'radar.Paul': ['Greengard:'],
#  'I': ['volunteered',
#   'really',
#   'was',
#   'spend',
#   'thought',
#   'was',
#   'learned',
#   'wouldn’t',
#   'did',
#   'was',
#   'mean',
#   'don’t',
#   'knew',
#   'think',
#   'wouldn’t',
#   'was',
#   'went',
#   'wanted',
#   'was',
#   'went',
#   'was',
#   'wanted',
#   'might',
#   'had',
#   'applied',
#   'applied',
#   'went.Did',
#   'learned',
#   'was',
#   'was',
#   'felt',
#   'felt',
#   'started',
#   'think',
#   'guess',
#   'was',
#   'did',
#   'guess,',
#   'actually',
#   'did',
#   'continued,',
#   'went',
#   'spent',
#   'was',
#   'was',
#   'would',
#   'was',
#   'wanted',
#   'went',
#   'was',
#   'left',
#   'felt',
#   'got',
#   'thought',
#   'could',
#   'felt',
#   'could',
#   'did.You',
#   'was',
#   'didn’t',
#   'would',
#   'was',
#   'think',
#   'started',
#   'was',
#   'thought,',
#   'knew',
#   'haven’t',
#   'present',
#   'never',
#   'was',
#   'don’t',
#   'never',
#   'was',
#   'was',
#   'had',
#   'did',
#   'was',
#   'mean',
#   'applied',
#   'got',
#   'wrote',
#   'actually',
#   'was',
#   'have',
#   'don’t',
#   'don’t',
#   'think',
#   'was',
#   'just',
#   'think',
#   'guess',
#   'think,',
#   'said,',
#   'think',
#   'just',
#   'left',
#   'just',
#   'was',
#   'wonder',
#   'mean',
#   'think',
#   'think',
#   'think',
#   'don’t',
#   'don’t',
#   'believe',
#   'think',
#   'believe',
#   'mean',
#   'think',
#   'know',
#   'was',
#   'do.',
#   'worked',
#   'do',
#   'can',
#   'was',
#   'guess',
#   'really',
#   'guess',
#   'want',
#   'wondered',
#   'was',
#   'was',
#   'was',
#   'spent',
#   'chose',
#   'don’t',
#   'know',
#   'would',
#   'suppose',
#   'mean.',
#   'was',
#   'think',
#   'think',
#   'think',
#   'have',
#   'ever',
#   'can',
#   'think',
#   'also',
#   'let',
#   'think',
#   'want',
#   'was',
#   'didn’t',
#   'took',
#   'hadn’t',
#   'want',
#   'said',
#   'know',
#   'found',
#   'thought',
#   'believe',
#   'really',
#   'think',
#   'really',
#   'got',
#   'really',
#   'try',
#   'will',
#   'think',
#   'had',
#   'mean',
#   'just',
#   'announced',
#   'had',
#   'think',
#   'had',
#   'mean',
#   'guess',
#   'didn’t',
#   'don’t',
#   'would',
#   'sit',
#   'don’t',
#   'was',
#   'didn’t',
#   'felt'],
#  'volunteered': ['in'],
#  'Navy.That': ['was'],
#  'during': ['the', 'the'],
#  'second': ['World', 'messenger', 'messenger', 'messenger'],
#  'World': ['War'],
#  'War': ['and'],
#  'that': ['was',
#   'time,',
#   'would',
#   'you',
#   'class',
#   'but',
#   'but',
#   'the',
#   'time',
#   'intersected',
#   'deflected',
#   'was',
#   'was',
#   'switched',
#   'I',
#   'was',
#   'spectrum',
#   'I',
#   'long',
#   'time',
#   'were',
#   'you',
#   'point?Paul',
#   'time,',
#   'time',
#   'period',
#   'one’s',
#   'and',
#   'was,',
#   'time',
#   'people',
#   'are',
#   'back',
#   'time,',
#   'at',
#   'time,',
#   'I',
#   'information',
#   'better',
#   'I',
#   'it',
#   'this',
#   'you’d',
#   'cyclic',
#   'work',
#   'the',
#   'was',
#   'maybe',
#   'way,',
#   'it',
#   'neuro',
#   'I',
#   'this',
#   'Sutherland',
#   'second',
#   'was',
#   'I',
#   'this',
#   'it’s',
#   'vision,',
#   'people',
#   'I',
#   'was',
#   'people',
#   'time,',
#   'people',
#   'today',
#   'time,',
#   'sort',
#   'I',
#   'keep',
#   'time,',
#   'previous',
#   'but',
#   'they',
#   'kind',
#   'exception?',
#   'they’ve',
#   'it’s',
#   'people',
#   'this',
#   'experiment',
#   'most',
#   'their',
#   'people',
#   'preceded',
#   'going',
#   'things',
#   'experience',
#   'and',
#   'room',
#   'are',
#   'never',
#   'idea',
#   'happens',
#   'support',
#   'there’s',
#   'different',
#   'provides',
#   'don’t',
#   'neurotransmitters',
#   'they’re',
#   'you',
#   'analogies',
#   'we',
#   'the',
#   'in',
#   'in',
#   'you',
#   'they',
#   'we’re',
#   'attitude.',
#   'some',
#   'our',
#   'I',
#   'the',
#   'the',
#   'drug',
#   'the',
#   'study',
#   '/-',
#   'the',
#   'will',
#   'some',
#   'initial',
#   'the',
#   'have',
#   'area',
#   'the',
#   'was',
#   'is',
#   'a',
#   'pharmacology',
#   'used',
#   'in',
#   'one',
#   'before',
#   'apply',
#   'and',
#   'we',
#   'happen',
#   'and',
#   'I',
#   'I’d',
#   'they',
#   'thing.',
#   'because',
#   'I',
#   'you’re',
#   'on',
#   'it’s',
#   'the',
#   'I',
#   'I’d',
#   'have'],
#  'straight': ['from'],
#  'school.': ['How'],
#  'How': ['did', 'did', 'did'],
#  'did': ['you',
#   'research,',
#   'was',
#   'it',
#   'not',
#   'a',
#   'lots',
#   'my',
#   'for',
#   'return',
#   'it',
#   'not.',
#   'for',
#   'funding',
#   'get',
#   'they',
#   'that',
#   'we',
#   'a'],
#  'find': ['your', 'interesting', 'out', 'any'],
#  'exposure': ['to'],
#  'research': ['work?Paul',
#   'in',
#   'are',
#   'to',
#   'questions',
#   'in',
#   'has',
#   'are',
#   'out',
#   'money',
#   'kind',
#   'now',
#   'which',
#   'that',
#   'from'],
#  'work?Paul': ['Greengard:'],
#  'really': ['didn’t',
#   'bad',
#   'were',
#   'talk',
#   'loved',
#   '…Paul',
#   'good',
#   'good',
#   'amazing,',
#   'hectic',
#   'kind',
#   'would',
#   'exciting',
#   'to',
#   'interesting,',
#   'try',
#   'still,',
#   'try',
#   'think.',
#   'want',
#   'have',
#   'funny.',
#   'like',
#   'love'],
#  'didn’t': ['do',
#   'exactly',
#   'really',
#   'know',
#   'go',
#   'show',
#   'believe',
#   'publish',
#   'and',
#   'even',
#   'want',
#   'want',
#   'know'],
#  'do': ['much',
#   'science',
#   'things',
#   'basically',
#   'it,',
#   'post-graduate',
#   'more',
#   'that',
#   'biomedical',
#   'something',
#   'their',
#   'the',
#   'in',
#   'now?',
#   'better',
#   'that,',
#   'it',
#   '…Paul',
#   'is',
#   'you',
#   'some',
#   'is',
#   'that,',
#   'this',
#   'something',
#   'toxicity',
#   'it',
#   'you',
#   'you',
#   'that.',
#   'you',
#   'way',
#   'and',
#   'now,',
#   'three',
#   'would',
#   'and',
#   'that.',
#   'that.It’s',
#   'it.I',
#   'with',
#   'something'],
#  'much': ['research',
#   'more',
#   'broader',
#   'broader',
#   'then.',
#   'to',
#   'belief',
#   'automatically',
#   'sense.',
#   'more',
#   'more',
#   'sense,',
#   'could',
#   'on',
#   'this',
#   'discriminated,',
#   'less',
#   'discrimination',
#   'indeed'],
#  'field': ['of', 'of', 'of', 'pretty'],
#  'electronics.': ['I'],
#  'quite': ['sure,',
#   'idealistic',
#   'productive',
#   'different',
#   'an',
#   'common',
#   'enthusiastic'],
#  'sure,': ['I'],
#  'spend': ['a'],
#  'a': ['period',
#   'microwave',
#   'radar',
#   'plane',
#   'lot.',
#   'technician',
#   'wonderful',
#   'really',
#   'kid',
#   'nice',
#   'physical',
#   'biological',
#   'lot',
#   'lecture',
#   'long',
#   'feeling',
#   'brain',
#   'remarkably',
#   'huge',
#   'field',
#   'great',
#   'very',
#   'thesis',
#   'biochemist',
#   'place',
#   'biochemistry',
#   'subsidiary',
#   'position',
#   'rather',
#   'large',
#   'much',
#   'very',
#   'pharmaceutical',
#   'much',
#   'protein',
#   'hormone',
#   'second',
#   'middle',
#   'very',
#   'large',
#   'smart',
#   'more',
#   'big',
#   'good',
#   'very',
#   'higher',
#   'grant',
#   'Nobel',
#   'psychological',
#   'lot',
#   'marginal',
#   'Nobel',
#   'way',
#   'next',
#   'next',
#   'complete',
#   'very',
#   'millisecond,',
#   'very',
#   'very',
#   'major,',
#   'prominent',
#   'very',
#   'couple',
#   'master',
#   'synapse',
#   'depression',
#   'small',
#   'sound',
#   'very',
#   'disease',
#   'couple',
#   'drug',
#   'new',
#   'dramatic',
#   'tremendous',
#   'sort',
#   'big',
#   'necessity',
#   'bit,',
#   'discipline.',
#   'neuroscience',
#   'pharmacology',
#   'biochemistry',
#   'physiology',
#   'few',
#   'problem,',
#   'draw',
#   'very',
#   'problem?Paul',
#   'problem',
#   'disease',
#   'particular',
#   'co-worker,',
#   'word',
#   'major',
#   'large',
#   'student',
#   'graduate',
#   'position,',
#   'scientist',
#   'very',
#   'graduate',
#   'funny',
#   'strong',
#   'correlation',
#   'very',
#   'very',
#   'structure',
#   'problem',
#   'number',
#   'problem,',
#   'presentation',
#   'major',
#   'pretty',
#   'difference',
#   'lot',
#   'single',
#   'pretty',
#   'very',
#   'very',
#   'good',
#   'victim',
#   'job',
#   'law',
#   'closed',
#   'compromise',
#   'nice',
#   'beloved',
#   'sculptor',
#   'Nobel',
#   'year'],
#  'period': ['of', 'while', 'for'],
#  'time': ['during',
#   'the',
#   'there',
#   'I',
#   'you',
#   'before',
#   'there',
#   'was',
#   'that',
#   'to',
#   'and',
#   'because',
#   'something',
#   'to',
#   'to'],
#  'war': ['up'],
#  'up': ['at',
#   'and',
#   'in',
#   'and',
#   'and',
#   'too',
#   'with',
#   'to',
#   'your',
#   'a',
#   'has',
#   'an',
#   '100.',
#   'and'],
#  'at': ['the',
#   'the',
#   'all',
#   'all',
#   'university',
#   'and',
#   'whatever',
#   'the',
#   'that',
#   'that',
#   'the',
#   'all',
#   'that',
#   'that',
#   'what',
#   'the',
#   'least',
#   'your',
#   'the',
#   'getting',
#   'least',
#   'the',
#   'the',
#   'grade',
#   'the',
#   'a',
#   'it',
#   'our',
#   'the'],
#  'Massachusetts': ['Institute'],
#  'Institute': ['of'],
#  'Technology': ['in'],
#  'what': ['is',
#   'the',
#   'you',
#   'I',
#   'I’d',
#   'at',
#   'I',
#   'I',
#   'followed',
#   'you’ve',
#   'I',
#   'did',
#   'has',
#   'if',
#   'they',
#   'the',
#   'their',
#   'the',
#   'they',
#   'is',
#   'they',
#   'are',
#   'look',
#   'the',
#   'they',
#   'I',
#   'it',
#   'kind',
#   'kind',
#   'level,',
#   'we',
#   'this',
#   'they',
#   'they',
#   'rotations',
#   'I',
#   'they'],
#  'called': ['the', 'the', 'somebody', 'and'],
#  'Radiation': ['Laboratory'],
#  'Laboratory': ['working', 'of'],
#  'working': ['on', 'in', 'again,', 'or', 'on', 'on', 'in'],
#  'development': ['of'],
#  'microwave': ['radar.'],
#  'radar.': ['At'],
#  'At': ['that', 'that', 'that', 'that', 'that', 'that', 'that', 'Rockefeller'],
#  'time,': ['one',
#   'old',
#   'just',
#   'doing',
#   'trying',
#   'because',
#   'funding',
#   'yes.',
#   'it'],
#  'one': ['of',
#   'is',
#   'was',
#   'was',
#   'of',
#   'of',
#   'cell',
#   'neuro',
#   'exception',
#   'who',
#   'and',
#   'of',
#   'looks',
#   'of',
#   'makes',
#   'will',
#   'very',
#   'of',
#   'of',
#   'of',
#   'was',
#   'of'],
#  'big': ['problems',
#   'difference',
#   'time.',
#   'shift',
#   'pharmaceutical',
#   'pharma',
#   'pharmaceuticals',
#   'pharmaceutical',
#   'shots',
#   'problem'],
#  'problems': ['for'],
#  'for': ['the',
#   'them.But',
#   'example,',
#   'a',
#   'which',
#   'instance,',
#   'decades',
#   'that',
#   'decades',
#   'a',
#   'saying',
#   'the',
#   'neurobiological',
#   'eight',
#   'me',
#   'me',
#   'the',
#   'almost',
#   'signal',
#   '15',
#   'this.',
#   'money',
#   'the',
#   'the',
#   'after',
#   'November',
#   'what',
#   '15',
#   'major',
#   'his',
#   'those',
#   'lack',
#   'it',
#   'a',
#   'a',
#   'neurotransmitters',
#   'these',
#   'them',
#   'developing',
#   'drug',
#   'the',
#   'it',
#   'new',
#   'a',
#   'in',
#   'and',
#   'most',
#   'that',
#   'example',
#   'women',
#   'four',
#   'several',
#   'their',
#   'their',
#   'the',
#   'having',
#   'taking',
#   'taking',
#   'achievements',
#   'popular'],
#  'United': ['States', 'States', 'States.', 'States', 'States.'],
#  'States': ['was', 'is', 'it’s'],
#  'these': ['kamikaze,',
#   'low',
#   'aircraft',
#   'antennae',
#   'physicists',
#   'two',
#   'days',
#   'were',
#   'cells',
#   'cyclic',
#   'fast-acting',
#   'intracellular',
#   'signalling',
#   'signalling',
#   'receptors',
#   'G-protein-coupled',
#   'slow',
#   'sorts',
#   'things',
#   'targets',
#   'compounds',
#   'clinical',
#   'biotech',
#   'days.Paul',
#   'days',
#   'potential',
#   'ideas',
#   'ideas',
#   'ruts,',
#   'letters,',
#   'people',
#   'discriminations',
#   'are',
#   'prizes'],
#  'kamikaze,': ['these'],
#  'low': ['flying'],
#  'flying': ['Japanese'],
#  'Japanese': ['aircraft'],
#  'aircraft': ['that', 'could', 'carrier.'],
#  'would': ['just',
#   'take',
#   'have',
#   'not',
#   'agree,',
#   'advise',
#   'be',
#   'you',
#   'do',
#   'just',
#   'see',
#   'be.',
#   'like',
#   'say',
#   'be',
#   'bestow',
#   'be,',
#   'be',
#   'appreciate',
#   'like',
#   'like',
#   'like'],
#  'just': ['fly',
#   'amazing.',
#   'a',
#   'seemed',
#   'about',
#   'take',
#   'going',
#   'wasn’t',
#   'raised',
#   'not',
#   'tried',
#   'adding',
#   'know',
#   'felt,',
#   'being',
#   'know',
#   'discovered',
#   'seems',
#   'modify',
#   'keep',
#   'completed',
#   'not',
#   'go',
#   'instinct,',
#   'published',
#   'doesn’t',
#   'sit',
#   'kept',
#   'unbelievable,',
#   'the',
#   'like'],
#  'fly': ['20'],
#  '20': ['feet', 'miles', 'miles.'],
#  'feet': ['above'],
#  'above': ['the'],
#  'water': ['and'],
#  'due': ['to'],
#  'curvature': ['of', 'of'],
#  'Earth,': ['these'],
#  'could': ['not',
#   'get',
#   'formulate',
#   'do',
#   'use',
#   'do',
#   'raise',
#   'not',
#   'make',
#   'I',
#   'say',
#   'be',
#   'say',
#   'say,',
#   'not'],
#  'be': ['detected',
#   'exposed',
#   'a',
#   'made',
#   'right,',
#   'important',
#   'presumably',
#   'good.',
#   'explained',
#   'lots',
#   'such',
#   'correct',
#   'known.',
#   'dozens',
#   'interested',
#   'a',
#   'another',
#   'this',
#   'done',
#   'gotten.',
#   'the',
#   'in',
#   'more',
#   'inhibiting',
#   'done',
#   'done',
#   'most',
#   'right,',
#   'very',
#   'giving',
#   'inhibited.Yes.',
#   'done.',
#   'on',
#   'nice'],
#  'detected': ['until'],
#  'until': ['they', 'he', 'somebody', 'we', 'this', '…'],
#  'they': ['were',
#   'took',
#   'were',
#   'had',
#   'had',
#   'were',
#   'were',
#   'won',
#   'were',
#   'really',
#   'did',
#   'did',
#   'release',
#   'do',
#   'have',
#   'do',
#   'pretty',
#   'evaluate',
#   'look',
#   'do',
#   'have',
#   'can',
#   'could',
#   '…',
#   'just',
#   'expect',
#   'better',
#   'must',
#   'prevail.',
#   'actually',
#   'somehow',
#   'were',
#   'stopped',
#   'do',
#   'are',
#   'would',
#   'say,',
#   'were,',
#   'tended',
#   'had',
#   'do',
#   'walk',
#   'trained',
#   'have,',
#   'didn’t',
#   'come',
#   'turned',
#   'want',
#   'want',
#   'do',
#   'have',
#   'do',
#   'want',
#   'were',
#   'were',
#   'are',
#   'haven’t',
#   'think',
#   'are.You',
#   'really',
#   'will',
#   'didn’t',
#   'were',
#   'were',
#   'won’t…Paul',
#   'saying',
#   'felt',
#   'said',
#   'cried',
#   'heard',
#   'present',
#   'were',
#   'present',
#   'say',
#   'really',
#   'asked'],
#  'about': ['20',
#   '20',
#   'that,',
#   'it',
#   'security',
#   'this',
#   'the',
#   'the',
#   'the',
#   'the',
#   'different',
#   'it,',
#   'being',
#   'genetics.One',
#   'it,',
#   'the',
#   'and',
#   'slow',
#   'the',
#   'how',
#   'what',
#   'pharmacology',
#   'earlier,',
#   'the',
#   'it,',
#   'before',
#   'him',
#   'having',
#   'how',
#   'having',
#   'how',
#   'publications',
#   'this',
#   'it',
#   'the',
#   'how',
#   'it.',
#   'it.',
#   'these',
#   'so',
#   'that.',
#   'it,'],
#  'miles': ['out.', 'north'],
#  'out.': ['They'],
#  'They': ['had', 'say:', 'look', 'say:', 'are', 'don’t'],
#  'had': ['these',
#   'the',
#   'no',
#   'these',
#   'two',
#   'been',
#   'learned',
#   'to',
#   'been',
#   'before?Paul',
#   'to',
#   'elucidated',
#   'advantages',
#   'that',
#   'the',
#   'a',
#   'other',
#   'grants',
#   'their',
#   'very',
#   'to',
#   'that',
#   'electrical',
#   'homogenizers',
#   'both',
#   'both',
#   'a',
#   'that',
#   'a',
#   'hundreds',
#   'assumed',
#   'a',
#   'a'],
#  'antennae': ['on'],
#  'tops': ['of'],
#  'ships': ['but'],
#  'that’s': ['still',
#   'what',
#   'what',
#   'where',
#   'where',
#   'what',
#   'helped',
#   'the',
#   'idea’s',
#   'the',
#   'why',
#   'not',
#   'the',
#   'a'],
#  'still': ['not', 'taking', 'wasn’t', 'is.', 'meant', 'be'],
#  'very': ['high',
#   'primitive',
#   'different',
#   'eccentric',
#   'educational',
#   'little',
#   'little',
#   'narrow',
#   'well-known',
#   'much',
#   'few',
#   'different',
#   'fortunate',
#   'happy',
#   'few',
#   'incomplete',
#   'incomplete',
#   'small',
#   'small',
#   'small',
#   'partial',
#   'little',
#   'creative',
#   'few',
#   'popular',
#   'interesting',
#   'close',
#   'promising',
#   'fortunate',
#   'interesting.',
#   'distinguished',
#   'gifted',
#   'distinguished',
#   'early',
#   'interesting',
#   'respectful.',
#   'enthusiastic',
#   'excited',
#   'enthusiastic,',
#   'clever',
#   'outstanding',
#   'successful',
#   'fact',
#   'prominent',
#   'nice.Is',
#   'busy',
#   'interesting.Paul',
#   'supportive',
#   'successful',
#   'much'],
#  'high': ['and', 'there', 'school'],
#  'so': ['the',
#   'the',
#   'on',
#   'I',
#   'they',
#   'ultra-concerned',
#   'I',
#   'on',
#   'on.Yes,',
#   'long?Paul',
#   'they',
#   'you',
#   'I',
#   'I',
#   'that’s',
#   'little',
#   'on',
#   'you',
#   'high',
#   'well,',
#   'hot,',
#   'instead',
#   'going',
#   'convinced',
#   'much',
#   'much',
#   'much',
#   'they',
#   'many',
#   'there’d',
#   'that',
#   'on.There’s',
#   'that',
#   'that’s',
#   'I',
#   'one',
#   'on.The',
#   'good',
#   'he',
#   'overwhelming',
#   'I',
#   'that',
#   'much',
#   'now',
#   'it’s',
#   'far',
#   'there’s',
#   'far',
#   'and',
#   'but',
#   'basically',
#   'we',
#   'it’s',
#   'much'],
#  'Earth': ['is'],
#  'such': ['that', 'nonsense?', 'that,', 'that', 'a', 'and', 'a', 'as'],
#  'can': ['only',
#   'do',
#   'consider',
#   'such',
#   'see',
#   'modify',
#   'still',
#   'attract',
#   'be',
#   'pick',
#   'anybody',
#   'you'],
#  'only': ['see',
#   'support',
#   'two',
#   'was',
#   '90%',
#   'way',
#   'like',
#   'a',
#   'had',
#   'had'],
#  'see': ['about', 'that', 'it.', 'Company', 'how', 'what', 'someone,', 'what'],
#  'miles.': ['This'],
#  'This': ['was', 'was', 'is', 'person', 'is', 'modulation', 'is', 'one'],
#  'days': ['of', 'you’d', 'people', 'and', 'and'],
#  'primitive': ['television'],
#  'television': ['so'],
#  'concept': ['was'],
#  'you’d': ['put', 'say', 'use', 'had', 'find', 'say'],
#  'put': ['a', 'in', 'them', 'forward'],
#  'radar': ['screen'],
#  'screen': ['in'],
#  'plane': ['and'],
#  'then': ['had',
#   'they',
#   'you',
#   'it',
#   'you',
#   'there',
#   'I',
#   'that',
#   'it',
#   'it',
#   'there’s',
#   'the',
#   'we',
#   'they’re',
#   'take',
#   'put',
#   'the',
#   'the',
#   'he',
#   'when',
#   'he',
#   'he',
#   'being',
#   'they’re',
#   'the',
#   'whenPaul',
#   'they',
#   'the'],
#  'image': ['projected'],
#  'projected': ['down'],
#  'down': ['to',
#   'glycogen.Showing',
#   'a',
#   'on.',
#   'right',
#   'the',
#   'tracks',
#   'with',
#   'but'],
#  'carrier.': ['I’d'],
#  'I’d': ['been', 'majored', 'laid', 'be', 'say', 'do', 'like', 'just'],
#  'sent': ['to'],
#  'electronic': ['school'],
#  'school': ['in', 'was', 'now,', 'in', 'he', 'of'],
#  'Navy': ['and'],
#  'took': ['two', 'so', 'him'],
#  'two': ['of',
#   'beams',
#   'beams',
#   'departments',
#   'types',
#   'groups',
#   'disciplines',
#   'nerve',
#   'in',
#   'weeks',
#   'prizes',
#   'prizes,'],
#  'us': ['from', 'do', 'profusely', 'know.', 'ane-mail.To'],
#  'class': ['to'],
#  'go': ['up',
#   'to',
#   'to',
#   'with',
#   'into',
#   'through',
#   'up',
#   'down',
#   'back',
#   'against',
#   'against',
#   'onto',
#   'there',
#   'to',
#   'by',
#   'on',
#   'and',
#   'to',
#   'through',
#   'here',
#   'and',
#   'up'],
#  'physicists': ['who'],
#  'who': ['were,',
#   'know',
#   'measured',
#   'would',
#   'was',
#   'said,',
#   'won',
#   'are',
#   'often',
#   'have',
#   'believe',
#   'are',
#   'aren’t',
#   'are',
#   'think',
#   'is',
#   'are',
#   'then',
#   'was',
#   'was',
#   'want',
#   'come',
#   'come',
#   'said',
#   'I',
#   'didn’t',
#   'we',
#   'we',
#   'come',
#   'thought',
#   'don’t',
#   'told',
#   'are',
#   'are',
#   'was',
#   'was',
#   'pick',
#   'give'],
#  'were,': ['I', 'especially'],
#  'thought': ['at', 'I', 'and', 'that', 'also', 'what', 'this'],
#  'old': ['men,'],
#  'men,': ['they'],
#  'probably': ['in', 'strike', 'an', 'know'],
#  'their': ['late',
#   'thinking',
#   'real',
#   'reward,',
#   'work',
#   'research.Paul',
#   'experiments',
#   'fellow',
#   'role?Paul',
#   'competitor’s',
#   'heads',
#   'attitude',
#   'strategy',
#   'laboratories',
#   'focus,',
#   'paranoid',
#   'work',
#   'ideas.Paul',
#   'comments',
#   'comments.Paul',
#   'travel,',
#   'part.How'],
#  'late': ['twenties'],
#  'twenties': ['but'],
#  'like': ['17,',
#   'a',
#   '10%',
#   'laying',
#   'October',
#   'that.',
#   'beyond',
#   'decades',
#   'a',
#   'interesting',
#   'to',
#   'to',
#   '80',
#   'do',
#   'them',
#   'them',
#   'we',
#   'my',
#   'other',
#   'seven',
#   'two',
#   'one',
#   'I',
#   'to',
#   'to',
#   'to',
#   'to'],
#  '17,': ['18.'],
#  '18.': ['It'],
#  'It': ['was',
#   'was',
#   'amazes',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'was',
#   'means',
#   'hurt',
#   'made',
#   'is',
#   'goes',
#   'was',
#   'seems'],
#  'amazing': ['place,', 'place.', 'for', 'in', 'thing.Paul'],
#  'place,': ['there', 'I'],
#  'there': ['were',
#   'were',
#   'were',
#   'and',
#   'wasn’t',
#   'was',
#   'for',
#   'was',
#   'was',
#   'that',
#   'was',
#   'just',
#   'are',
#   'were',
#   'must',
#   'are',
#   'are',
#   'are',
#   'are',
#   'and',
#   'rather',
#   'are',
#   'and'],
#  'several': ['of',
#   'layers',
#   'years',
#   'things',
#   'laboratories.',
#   'examples',
#   'years'],
#  'them': ['went',
#   'so',
#   'together?Paul',
#   'and',
#   'another',
#   'and',
#   'away.',
#   'and',
#   'and',
#   'and',
#   'off',
#   'and',
#   'into',
#   'or',
#   'before',
#   'to',
#   'pass',
#   'if',
#   'out',
#   'down',
#   'and',
#   'saying',
#   'to',
#   'all'],
#  'went': ['onto', 'on', 'to', 'to', 'onto', 'on', 'into', 'back.', 'to'],
#  'onto': ['win', 'your', 'what’s', 'it.Obviously'],
#  'win': ['Nobel'],
#  'Prizes': ['in', 'and', '2023Eleven'],
#  'Physics': ['and'],
#  'learned': ['a', 'from', 'a'],
#  'lot.': ['I'],
#  'wouldn’t': ['say', 'do'],
#  'say': ['I',
#   'that',
#   'that',
#   'you',
#   'we’re',
#   'they',
#   'the',
#   'today,',
#   'that',
#   'would',
#   'their',
#   'the',
#   'most',
#   'that’s',
#   'what',
#   'they'],
#  'research,': ['I', 'didn’t'],
#  'technician': ['doing'],
#  'doing': ['things',
#   'science',
#   'that,',
#   'that',
#   'it.',
#   'enzymological',
#   'that',
#   'biomedical',
#   'that,',
#   'this',
#   'very',
#   'is',
#   'is',
#   'is',
#   'that,'],
#  'things': ['for',
#   'with',
#   'that',
#   'but',
#   'are',
#   'are.',
#   'up',
#   'are',
#   'that',
#   'about',
#   'as'],
#  'them.But': ['a'],
#  'wonderful': ['environment.Paul', 'for'],
#  'environment.Paul': ['Greengard:'],
#  'place.': ['It'],
#  'amazes': ['me,'],
#  'me,': ['the', 'I', 'he’d', 'so'],
#  'highest': ['security'],
#  'security': ['level', 'lapse', 'then.Yes,'],
#  'level': ['in'],
#  'top': ['secret', 'of'],
#  'secret': ['and', 'and', 'information'],
#  'next': ['one', 'five', 'obvious', 'obvious', 'generation'],
#  'many': ['people',
#   'different',
#   'Nobel',
#   'good',
#   'great',
#   'of',
#   'more',
#   'of',
#   'schools'],
#  'people': ['get',
#   'who',
#   'weren’t',
#   'studying',
#   'that',
#   'to',
#   'would',
#   'were',
#   'wanting',
#   'appreciate',
#   'did',
#   'didn’t',
#   'began',
#   'disagreed',
#   'said,',
#   'describe',
#   'saying',
#   'for',
#   'as',
#   'who',
#   'go',
#   'wrong',
#   'who',
#   'who',
#   'in',
#   'working',
#   'on',
#   'who',
#   'doing',
#   'who',
#   'with',
#   'who',
#   'have',
#   'know',
#   'do.',
#   'deciding',
#   'I',
#   'to,',
#   'were',
#   'tell',
#   'are',
#   'on',
#   'on',
#   'and',
#   'who'],
#  'get': ['to',
#   'to',
#   'your',
#   'at',
#   'a',
#   'funding',
#   'good',
#   'it?',
#   'a',
#   'any',
#   'accepted',
#   'proven',
#   'the',
#   'around',
#   'around',
#   'into',
#   'into',
#   'more',
#   'the',
#   'the',
#   'a'],
#  'our': ['project,', 'department', 'department', 'data', 'group', 'lab'],
#  'project,': ['we'],
#  'we': ['were',
#   'had',
#   'knew',
#   'need',
#   'don’t',
#   'need',
#   'do,',
#   'found',
#   'found',
#   'had',
#   'actually',
#   'got',
#   'now?Paul',
#   'have',
#   'just',
#   'probably',
#   'know',
#   'can',
#   'don’t',
#   'have',
#   'go',
#   'were',
#   'should',
#   'should',
#   'were',
#   'were',
#   'all',
#   'all',
#   'were',
#   'set',
#   'really',
#   'had',
#   'haven’t'],
#  'all': ['given',
#   'sorts',
#   'to',
#   'that',
#   'the',
#   'in',
#   'made',
#   'paranoid,',
#   'part',
#   'the',
#   'the',
#   'biologists',
#   'sorts',
#   'develop',
#   'tend',
#   'the',
#   'that.',
#   'women,',
#   'fields.',
#   'this',
#   'presented'],
#  'given': ['clearance', 'you', 'like', 'for', 'a'],
#  'clearance': ['to'],
#  'look': ['at', 'back,', 'at', 'like', 'for', 'for'],
#  'sorts': ['of', 'of', 'of'],
#  'information': ['and', 'to', 'about'],
#  'it’s': ['just',
#   'going',
#   'part',
#   'interesting,',
#   'nice',
#   'been',
#   'a',
#   'got',
#   'my',
#   'a',
#   'somewhat',
#   'a',
#   'much',
#   'much',
#   'probably',
# ...
#  'into': ['disciplinary',
#   'this',
#   'medicine,',
#   'an',
#   'drug',
#   'clinical',
#   'phase',
#   'the',
#   'the',
#   'these',
#   'that'],
#  'disciplinary': ['research'],
#  'unite': ['disciplines.'],
#  'disciplines.': ['Did'],
#  'Did': ['you'],
#  'feel': ['you', 'to', 'that', 'that', 'that'],
#  'back': ['then,', 'to', 'to', 'and', 'to', 'to'],
#  'then,': ['were', 'as'],
#  'crusading': ['to', 'to'],
#  'bring': ['them'],
#  'together?Paul': ['Greengard:'],
#  'persuade': ['other'],
#  'it,': ['I', 'it', 'I', 'it’s', 'you', 'it’s', 'but', 'so', 'she’s'],
#  'considered': ['a', 'an'],
#  'eccentric': ['approach,'],
#  'approach,': ['I'],
#  'guess,': ['but'],
#  'fairness': ['to'],
#  'faculty': ['of'],
#  'oppose': ['my'],
#  'actually': ['did', 'called', 'said,', 'get', 'positively', 'get'],
#  'thesis': ['under', 'in'],
#  'under': ['the'],
#  'joint': ['supervision'],
#  'supervision': ['of'],
#  'physiologist': ['in'],
#  'biochemist': ['who'],
#  'Moccollum': ['Pratt'],
#  'Pratt': ['Institutewhich'],
#  'Institutewhich': ['was'],
#  'basically,': ['as'],
#  'as': ['a',
#   'head',
#   'the',
#   'the',
#   'well',
#   'applying',
#   'quite',
#   'I',
#   'you',
#   'DARPP-32',
#   'drug',
#   'all',
#   'Genentech',
#   'a',
#   'a',
#   'they',
#   'I',
#   'you',
#   'president,'],
#  'subsidiary': ['of'],
#  'lots': ['of', 'of', 'of', 'of', 'of', 'of', 'of', 'of'],
#  'enzymology': ['and'],
#  'so.': ['It'],
#  'prominent': ['places', 'phenomenon', 'women'],
#  'places': ['in', 'where'],
#  'enzymological': ['kinds'],
#  'kinds': ['of', 'by', 'of'],
#  'work,': ['so', 'it', 'they’re'],
#  'interface': ['between'],
#  'between': ['electrophysiology',
#   'the',
#   'what',
#   'two',
#   'biophysics',
#   'them?',
#   'people'],
#  'selling': ['the'],
#  'impulse.As': ['I'],
#  'continued,': ['then'],
#  'post-graduate': ['work.'],
#  'work.': ['I', 'The', 'It’s'],
#  'spent': ['five', 'by', 'several'],
#  'five': ['years', 'or', 'years'],
#  'England': ['and'],
#  'continued': ['to'],
#  'boundary': ['between'],
#  'disciplines': ['and'],
#  'virtually': ['nobody', 'everyone'],
#  'nobody': ['was', 'picked', 'knew'],
#  'understand': ['the'],
#  'neurobiological': ['phenomenon.'],
#  'phenomenon.': ['Then'],
#  'offered': ['a'],
#  'position': ['as', 'and'],
#  'head': ['of', 'of', 'of'],
#  'Geigy': ['Pharmaceuticals,'],
#  'Pharmaceuticals,': ['today'],
#  'today': ['it’s', 'you', 'is'],
#  'part': ['of', 'of', 'of', 'of', 'of', 'of', 'just'],
#  'Novartis.': ['I'],
#  'difference': ['in', 'in', 'of'],
#  'salary': ['between'],
#  'truly': ['it'],
#  '10%': ['or'],
#  'something,': ['but', 'but'],
#  'idealistic': ['and'],
#  'scientific': ['approaches', 'knowledge.'],
#  'new': ['drug',
#   'drugs.',
#   'ideas,',
#   'drug,',
#   'ways',
#   'story',
#   'programme',
#   'drugs',
#   'drugs',
#   'leads'],
#  'drug': ['development,',
#   'targets,',
#   'targets,',
#   'developed',
#   'target',
#   'industry',
#   'industry',
#   'and',
#   'to',
#   'companies',
#   'companies',
#   'companies,',
#   'development,',
#   'companies',
#   'and',
#   'company',
#   'works.Turning'],
#  'development,': ['so', 'the'],
#  'company': ['and', 'did', 'environments'],
#  'years.': ['It'],
#  'rather': ['exciting', 'than'],
#  'exciting': ['period', 'new', 'and'],
#  'left': ['because', 'Geigy,', 'since,', 'my', 'and'],
#  'everything': ['was'],
#  'done': ['by', 'very', 'some', 'since', 'within', 'in', 'in', 'in', 'it'],
#  'committees': ['and', 'as', 'I’ve', 'have'],
#  'large': ['extent', 'part', 'what', 'number'],
#  'extent': ['it'],
#  'is.': ['Some'],
#  'Some': ['of', 'of', 'of'],
#  'avant': ['garde,'],
#  'garde,': ['the'],
#  'agree': ['to', 'pretty'],
#  'unless': ['the'],
#  'committee': ['would', 'which', 'are', 'are'],
#  'agree,': ['it'],
#  'done.': ['I', 'He', 'Then'],
#  'frustrated': ['and'],
#  'terms': ['of', 'of', 'of', 'of', 'about', 'of'],
#  'basic': ['biology', 'philosophy', 'principle', 'picture', 'research'],
#  'drugs': ['and', 'is', 'came', 'a'],
#  'develop': ['new', 'drugs.', 'think'],
#  'drugs.': ['I', 'The'],
#  'did.You': ['went'],
#  'back.': ['That'],
#  'That': ['interlude', 'was', 'was', 'is'],
#  'interlude': ['must'],
#  'must': ['have', 'have', 'have', 'have', 'be'],
#  'perspective': ['on'],
#  'followed': ['and'],
#  'productive': ['if', 'relationships'],
#  'if': ['you',
#   'you’re',
#   'you',
#   'they',
#   'everybody',
#   'you',
#   'you’re',
#   'they’re',
#   'that’s',
#   'you',
#   'there’s',
#   'you',
#   'you',
#   'the',
#   'you',
#   'they',
#   'you',
#   'they',
#   'they',
#   'you',
#   'I'],
#  'stayed': ['eight'],
#  'years,': ['you'],
#  'loved': ['it.Paul'],
#  'it.Paul': ['Greengard:'],
#  'educational': ['because'],
#  'division': ['I'],
#  'obliged': ['to'],
#  'learn': ['lots'],
#  'stuff': ['that'],
#  'anything': ['about.', 'but', 'exciting,', 'yet,', 'to'],
#  'about.': ['In'],
#  'In': ['those', 'Europe,', 'the', 'fact', 'fact,', 'fact,'],
#  'those': ['days', 'who', 'discoveries.', 'as', 'targets?Paul'],
#  'biomedical': ['research,', 'research', 'research'],
#  'medicine,': ['there'],
#  'little': ['known', 'available,', 'scientific', 'thinking'],
#  'diseases': ['and', 'and', 'of'],
#  'laying': ['on'],
#  'hands': ['and'],
#  'comforting': ['patients,'],
#  'patients,': ['there'],
#  'very,': ['very', 'very'],
#  'available,': ['very'],
#  'knowledge.': ['The'],
#  'situation': ['is'],
#  'now': ['and', 'is', 'that', 'are', 'is', 'in', 'can', 'in', 'we', 'really'],
#  'advise': ['young'],
#  'young': ['people', 'person’s', 'people', 'people', 'person'],
#  'wanting': ['to'],
#  'through': ['medical', 'the', 'that', 'the'],
#  'now,': ['at', 'we', 'there’s', 'the'],
#  'least': ['through', 'on'],
#  'curriculum,': ['so'],
#  'broader': ['education.', 'education'],
#  'education.': ['I'],
#  'educated': ['in'],
#  'narrow': ['area'],
#  'area': ['and', 'where', 'was', 'but'],
#  'functions': ['that'],
#  'being': ['a',
#   'November',
#   'isolated',
#   'lost',
#   'either',
#   'bought',
#   'successful'],
#  'pharmaceutical': ['company',
#   'industry.',
#   'industry',
#   'industry,',
#   'industry',
#   'companies',
#   'companies',
#   'companies',
#   'companies.Still'],
#  'give': ['me', 'a', 'you', 'their', 'the'],
#  'education': ['in', 'to'],
#  'areas': ['of'],
#  'medicine': ['and'],
#  'helped': ['me'],
#  'ensuing': ['decades.When'],
#  'decades.When': ['you'],
#  'Geigy,': ['you'],
#  'return': ['basically', 'to'],
#  'same': ['research', 'discovery', 'time', 'idea', 'thing,', 'thing'],
#  'questions': ['that'],
#  'before?Paul': ['Greengard:'],
#  'Pretty': ['much,'],
#  'much,': ['nobody'],
#  'picked': ['it', 'to', 'by'],
#  'meanwhile': ['and'],
#  'again,': ['the'],
#  'projects': ['were'],
#  'somewhat': ['different', 'more'],
#  'philosophy': ['was', 'in'],
#  'same.Earl': ['Sutherlandhad'],
#  'Sutherlandhad': ['shown'],
#  'shown': ['that'],
#  'cyclic': ['AMP', 'AMP', 'AMP,', 'AMP'],
#  'AMP': ['mediated', 'activated', 'activated'],
#  'mediated': ['the'],
#  'actions': ['of'],
#  'hormones': ['and', 'are'],
#  'I’ve': ['been',
#   'seen,',
#   'served',
#   'seen',
#   'even',
#   'sat',
#   'had',
#   'been',
#   'talked',
#   'heard',
#   'had',
#   'had',
#   'talked',
#   'seen'],
#  'following': ['that'],
#  'ever': ['since', 'appearing,', 'interview', 'on'],
#  'always': ['interested', 'questioning', 'looking'],
#  'me.': ['ThenEd', 'This'],
#  'ThenEd': ['Krebs'],
#  'Krebs': ['together', 'had'],
#  'together': ['withFischershowed'],
#  'withFischershowed': ['that'],
#  'activated': ['a', 'protein'],
#  'protein': ['kinase', 'phosphorylation', 'kinase', 'phosphorylation'],
#  'kinase': ['and', 'activity'],
#  'broke': ['down'],
#  'glycogen.Showing': ['protein'],
#  'phosphorylation': ['in', 'in', 'was'],
#  'yes.Paul': ['Greengard:', 'Greengard:'],
#  'liver': ['and'],
#  'muscle': ['and'],
#  'released': ['by'],
#  'cell': ['and', 'and'],
#  'another,': ['it'],
#  'possibly': ['occurred'],
#  'maybe': ['neurotransmitters', 'this', 'part'],
#  'neurotransmitters': ['worked', 'modulate', 'where', 'and'],
#  'worked': ['that', 'on,', 'in', 'in'],
#  'way,': ['they', 'so'],
#  'release': ['from'],
#  'act': ['on'],
#  'another.': ['I'],
#  'thought,': ['maybe'],
#  'present': ['in', 'our', 'the', 'it,', 'the', 'it,'],
#  'found': ['that', 'that', 'these', 'earlier,', 'myself'],
#  'was.': ['We'],
#  'transmitters': ['could'],
#  'raise': ['the'],
#  'levels': ['of'],
#  'AMP,': ['we'],
#  'enormously': ['higher'],
#  'higher': ['concentration', 'bar'],
#  'concentration': ['than'],
#  'elsewhere,': ['but'],
#  'synapse,': ['the'],
#  'junction': ['between'],
#  'right,': ['that', 'it', 'I’d', 'at', 'you’re', 'it', 'so', 'I'],
#  'principle': ['that'],
#  'Sutherland': ['and', 'in', 'who'],
#  'elucidated': ['in'],
#  'hormone': ['making'],
#  'making': ['a'],
#  'messenger': ['go', 'regulating', 'systems'],
#  'regulating': ['protein'],
#  'important': ['in', 'what', 'element', 'things'],
#  'haven’t': ['left', 'set', 'mentioned'],
#  'since,': ['that'],
#  '40': ['years'],
#  'ago.If': ['it'],
#  'unusual': ['to'],
#  'middle': ['path'],
#  'path': ['between'],
#  'earlier,': ['it', 'but', 'that'],
#  'positively': ['heretical', 'push'],
#  'heretical': ['to'],
#  'systems': ['newly'],
#  'newly': ['discovered'],
#  'discovered': ['by', 'fire,', 'a'],
#  'Earl': ['Sutherland', 'Sutherland'],
#  '1960s.': ['How'],
#  'interesting.': ['It', 'The'],
#  'data': ['and'],
#  'once': ['a'],
#  'well-known': ['person'],
#  'person': ['got', 'thinks', 'publishes', 'who', 'just'],
#  'said,': ['This', 'Even', 'Well,', 'We', 'it’s', 'this'],
#  'heretical,': ['this'],
#  'ridiculous,': ['why'],
#  'talking': ['such',
#   'to.',
#   'about',
#   '100s',
#   'about',
#   'about',
#   'earlier',
#   'about'],
#  'nonsense?': ['It'],
#  'hurt': ['my'],
#  'feelings': ['but'],
#  'interesting,': ['I', 'I'],
#  'doubted': ['that', 'I'],
#  'right.': ['I', 'I’m', 'The', 'It’s'],
#  'negative': ['reactions,'],
#  'reactions,': ['I'],
#  'right': ['and',
#   'and',
#   'track.Nowadays',
#   'after',
#   'after',
#   'it',
#   'but',
#   'now',
#   'approach',
#   'now,',
#   'but',
#   'now',
#   'afterwards,'],
#  'turned': ['out', 'down', 'down?Paul', 'down.', 'down', 'him'],
#  'advantages': ['and'],
#  'disadvantages.': ['The'],
#  'disadvantage': ['was', 'that'],
#  'appreciate': ['your', 'your'],
#  'then.': ['The'],
#  'exception': ['was', 'that', 'that', 'to'],
#  'Even': ['if', 'so'],
#  'you’re': ['only',
#   'just',
#   'positive,',
#   'going',
#   'talking',
#   'modest.',
#   'doing',
#   'a',
#   'talking',
#   'at,'],
#  '90%': ['right,', 'of', 'of'],
#  'meant': ['that', 'to'],
#  'extremely': ['important', 'talented', 'helpful'],
#  'you’ve': ['done.', 'already', 'got'],
#  'He': ['had'],
#  'vision,': ['he'],
#  'appreciated': ['what', 'and', 'earlier'],
#  'doing,': ['but'],
#  'most': ['people',
#   'Nobel',
#   'of',
#   'of',
#   'from',
#   'important',
#   'helpful',
#   'gifted',
#   'Nobel',
#   'important',
#   'outstanding',
#   'of'],
#  'not.': ['That'],
#  'show': ['any'],
#  'appreciation': ['or', 'is'],
#  'few': ['did', 'ideas', 'exceptions', 'exceptions.Yes,'],
#  'advantage': ['was'],
#  'pretty': ['much', 'much', 'open,', 'much', 'clever', 'prestigious'],
#  'myself,': ['the'],
#  'signal': ['transduction', 'transduction'],
#  'transduction': ['for', 'in'],
#  '15': ['years', 'years', 'years'],
#  'began': ['to'],
#  'realise': ['it'],
#  'laid': ['out'],
#  'foundation': ['for', 'for'],
#  'brain.Right.': ['How'],
#  'funding': ['work',
#   'for',
#   'was',
#   'even',
#   'both',
#   'them',
#   'or',
#   'because',
#   'for'],
#  'nowadays,': ['to'],
#  'something': ['that', 'like', 'gets', 'like', 'really', 'like', 'of'],
#  'disagreed': ['with'],
#  'presumably': ['impossible.Paul'],
#  'impossible.Paul': ['Greengard:'],
#  'That’s': ['an', 'true', 'a', 'a'],
#  'excellent': ['question.'],
#  'question.': ['The'],
#  'fact': ['is', 'this', 'they'],
#  'this.': ['At', 'I'],
#  'fairly': ['liberal', 'informed'],
#  'liberal': ['and'],
#  'Well,': ['he’s', 'he', 'you’ve'],
#  'he’s': ['a', 'on'],
#  'smart': ['chap,'],
#  'chap,': ['he’s'],
#  'wrong': ['track', 'track.', 'or', 'and', 'or'],
#  'track': ['but', 'record,'],
#  'let’s': ['fund', 'fund', 'have'],
#  'fund': ['him', 'them'],
#  'him': ['until', 'down.', 'and', 'and', 'before'],
#  'comes': ['to', 'out'],
#  'his': ['senses,', 'time,', 'ideas', 'desk,'],
#  'senses,': ['it'],
#  'sort': ['of', 'of', 'of', 'of', 'of', 'of', 'of', 'and'],
#  'thing.': ['I', 'There'],
#  'though': ['there'],
#  'belief': ['in'],
#  'track.Nowadays': ['people'],
#  'describe': ['how'],
#  'real': ['passion'],
#  'passion': ['on'],
#  'side': ['and', 'is'],
#  'pot': ['boiler'],
#  'boiler': ['experiments'],
#  'experiments': ['that', 'where', 'were', 'are', 'are'],
#  'reviewers': ['and'],
#  'grant': ['awarding', 'application', 'application', 'I', 'deadline'],
#  'awarding': ['bodies'],
#  'bodies': ['happy'],
#  'happy': ['and', 'childhoods.', 'to'],
#  'parallel.': ['But'],
#  'But': ['you', 'then,', 'anyhow,'],
#  'wholeheartedly.Paul': ['Greengard:'],
#  'yes.': ['But'],
#  'competition': ['for'],
#  'money': ['got', 'for', 'for', 'to', 'should,'],
#  'tougher,': ['I'],
#  'everyone': ['now'],
#  'forced': ['to'],
#  'already': ['done', 'known,', 'paying'],
#  'logical': ['presentation.'],
#  'presentation.': ['There’s'],
#  'Europe': ['vs'],
#  'vs': ['the'],
#  'States.': ['In', 'Each'],
#  'Europe,': ['if'],
#  'record,': ['they'],
#  'automatically': ['give'],
#  'ten': ['years', 'years'],
#  'evaluate': ['people,'],
#  'people,': ['they', 'they', 'there’s'],
#  'back,': ['what'],
#  'previous': ['period?'],
#  'period?': ['In'],
#  'philosophy.': ['They'],
#  'say:': ['Well,', 'This'],
#  'has': ['he',
#   'doubts',
#   'to',
#   'to',
#   'explained',
#   'transformed',
#   'such',
#   'been',
#   'almost',
#   'this',
#   'invited',
#   'witnessed'],
#  'fire,': ['what’s'],
#  'what’s': ['he', 'already', 'the'],
#  'now?': ['They'],
#  'application': ['and', 'is'],
#  'good.': ['I’ve'],
#  'seen,': ['because'],
#  'served': ['on'],
#  'well': ['as', 'you’re', 'known'],
#  'committees,': ['I’ve'],
#  'seen': ['both', 'almost', 'the', 'so'],
#  'both': ['kinds', 'ways', 'in', 'because', 'types', 'of'],
#  'guy’s': ['really'],
#  'woman’s': ['really'],
#  'another': ['five', 'drug', 'very', 'committee'],
#  'although': ['the'],
#  'written': ['so'],
#  'cases,': ['I’ve'],
#  'inverse': ['discrimination.'],
#  'discrimination.': ['They'],
#  'thinks': ['they’re'],
#  'they’re': ['so',
#   'there,',
#   'wrong,',
#   'right',
#   'talking',
#   'pretty',
#   'continuously',
#   'becoming',
#   'being',
#   'told',
#   'always',
#   'always',
#   'not',
#   'going',
#   'just'],
#  'hot,': ['and'],
#  'impression': ['from'],
#  'sat': ['on'],
#  'bar': ['for', 'for'],
#  'accomplished': ['people,'],
#  'kind': ['of', 'of', 'of', 'of', 'of'],
#  'thing.I’ve': ['seen'],
#  'bias': ['both', 'that'],
#  'own': ['case,', 'case', 'work,', 'career'],
#  'case,': ['the'],
#  'Prize,': ['I', 'there', 'last'],
#  'on.': ['That'],
#  'amazing,': ['we', 'watching'],
#  'deadline': ['in'],
#  'November': ['1,', '1,'],
#  '1,': ['and', 'could'],
#  'October': ['10'],
#  '10': ['or'],
#  'that.': ['I', 'I', 'A', 'They’ll', 'I', 'She'],
#  'wrote': ['and'],
#  'somebody': ['at', 'else', 'in', 'interested', 'from', 'will'],
#  'institute': ['I'],
#  'to,': ['to', 'but'],
#  'ask': ['if', 'is,'],
#  'make': ['an', 'the', 'more', 'up', 'comments'],
#  'exception,': ['so'],
#  'instead': ['of'],
#  'extra': ['two'],
#  'weeks': ['because'],
#  'hectic': ['right'],
#  'woman': ['actually', 'in', 'not', 'ever', 'named'],
#  'can’t': ['do', 'approach', 'wait', 'just', 'be'],
#  'everybody': ['who', 'was'],
#  'exception?': ['It’s'],
#  'It’s': ['really', 'almost', 'easy', 'just', 'a', 'a', 'a', 'an', 'been'],
#  'watching': ['the'],
#  'bureaucracy.So': ['there'],
#  'down?Paul': ['Greengard:'],
#  'remember,': ['did'],
#  'it?': ['Yes,'],
#  'down.': ['I’ve', 'I'],
#  'Laureates': ['tell', 'who', 'have', 'are', 'on'],
#  'tell': ['me', 'about'],
#  'they’ve': ['had', 'had', 'got', 'published', 'been'],
#  'grants': ['turned'],
#  'raised': ['the'],
#  'expect': ['or'],
#  'psychological': ['thing.Yes,'],
#  'thing.Yes,': ['they’ve'],
#  'reward,': ['they'],
#  'Yes.': ['But', 'It'],
#  'anyhow,': ['to'],
#  'earlier': ['question,', 'days', 'about', 'on'],
#  'fortunate': ['at', 'because', 'having'],
#  'getting': ['funding', 'criticised', 'letters'],
#  'difficult': ['or', 'now.Just'],
#  'now.Just': ['to'],
#  'inner': ['confidence'],
#  'confidence': ['that'],
#  'believing': ['you'],
#  'occasionally': ['you'],
#  'criticised': ['by'],
#  'good,': ['so'],
#  'track.': ['You'],
#  'You': ['say', 'moved'],
#  'doubted,': ['I'],
#  'that’d': ['probably'],
#  'strike': ['people'],
#  'extraordinary': ['degree'],
#  'self-belief.Paul': ['Greengard:'],
#  'true': ['and'],
#  'ultra,': ['ultra'],
#  'ultra': ['confident,'],
#  'confident,': ['they'],
#  ...}

# %% [markdown]
# ## Create a Text Generator

# %% [markdown]
# We're going to create a function that generates sentences. It will take two things as inputs:
# * The dictionary you just created
# * The number of words you want generated
#
# Here are some examples of generated sentences:
#
# >'Shape right turn– I also takes so that she’s got women all know that snail-trail.'
#
# >'Optimum level of early retirement, and be sure all the following Tuesday… because it’s too.'

# %%
import random

def generate_sentence(chain, count=15):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # End it with a period
    sentence += '.'
    return(sentence)

# %%
generate_sentence(paul_dict)
# Out:
# 'Targets in retrospect. I’ve talked to do …Paul Greengard: Thank you.Watch the aircraft that I.'

# %% [markdown]
# ### Assignment:
# 1. Generate sentence for other comedians also.
# 2. Try making the generate_sentence function better. Maybe allow it to end with a random punctuation mark or end whenever it gets to a word that already ends with a punctuation mark.
